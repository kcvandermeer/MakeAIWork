# %%
#!/usr/bin/env python

# %%
import pandas as pd
# print(pd.__version__)
import numpy as np

# make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)

import tensorflow as tf
keras = tf.keras

from tensorflow.keras.models import Model

# %%
lidar_data = pd.read_csv(
    "C:/Users/kcvan/MakeAIWork/KEVINPROJECT1/CSVfiles/04_L_300922 - 04_L_300922.csv",
    names=["Lidar1", "Lidar2", "Lidar3", "Lidar4", "Lidar5", "Lidar6", "Lidar7", "Lidar8", "Lidar9", "Lidar10",
           "Lidar11", "Lidar12", "Lidar13", "Lidar14", "Lidar15", "Lidar16", "SteeringAngle"])

lidar_data.head()
# Out:
#    Lidar1  Lidar2  Lidar3   Lidar4   Lidar5   Lidar6  Lidar7  Lidar8   Lidar9  \
# 0  7.4738  6.8804  8.4187  10.2916  12.9601   9.7649  5.7678  5.8949   3.9631
# 1  7.4734  6.8800  8.4183  10.2912  12.9597   9.7646  5.7675  5.8946   3.9629
# 2  7.4734  6.8800  8.4183  10.2912  12.9597   9.7646  5.7675  5.8946   3.9629
# 3  7.4700  6.8767  8.4153  10.2884  12.9573  11.2625  5.7657  5.8933  20.0000
# 4  7.4670  6.8739  8.4128  10.2860  12.9552  11.2607  5.7641  5.8923  20.0000
#
#    Lidar10  Lidar11  Lidar12  Lidar13  Lidar14  Lidar15  Lidar16  \
# 0  20.0000   5.2666   2.7754   4.3291   5.5480   1.4787   6.4672
# 1  20.0000   5.2664   2.7751   4.3287   5.5477   1.4783   6.4667
# 2  20.0000   5.2664   2.7751   4.3287   5.5477   1.4783   6.4667
# 3  20.0000   5.2634   2.7719   4.3254   5.5442   1.4747   6.4631
# 4   1.2853   5.2609   2.7692   4.3226   5.5412   4.8172   1.4716
#
#    SteeringAngle
# 0          -32.0
# 1          -32.0
# 2          -32.0
# 3          -31.5
# 4          -39.0

# %%
# print(lidar_data)

# %%
lidar_sensors = lidar_data.copy()
lidar_angle = lidar_sensors.pop('SteeringAngle')
lidar_sensors.head()
# Out:
#    Lidar1  Lidar2  Lidar3   Lidar4   Lidar5   Lidar6  Lidar7  Lidar8   Lidar9  \
# 0  7.4738  6.8804  8.4187  10.2916  12.9601   9.7649  5.7678  5.8949   3.9631
# 1  7.4734  6.8800  8.4183  10.2912  12.9597   9.7646  5.7675  5.8946   3.9629
# 2  7.4734  6.8800  8.4183  10.2912  12.9597   9.7646  5.7675  5.8946   3.9629
# 3  7.4700  6.8767  8.4153  10.2884  12.9573  11.2625  5.7657  5.8933  20.0000
# 4  7.4670  6.8739  8.4128  10.2860  12.9552  11.2607  5.7641  5.8923  20.0000
#
#    Lidar10  Lidar11  Lidar12  Lidar13  Lidar14  Lidar15  Lidar16
# 0  20.0000   5.2666   2.7754   4.3291   5.5480   1.4787   6.4672
# 1  20.0000   5.2664   2.7751   4.3287   5.5477   1.4783   6.4667
# 2  20.0000   5.2664   2.7751   4.3287   5.5477   1.4783   6.4667
# 3  20.0000   5.2634   2.7719   4.3254   5.5442   1.4747   6.4631
# 4   1.2853   5.2609   2.7692   4.3226   5.5412   4.8172   1.4716

# %%
#print(lidar_sensors)

# %%
#lidar_angle.head()

# %%
lidar_sensors = np.array(lidar_sensors)
lidar_sensors
# Out:
# array([[ 7.474,  6.88 ,  8.419, ...,  5.548,  1.479,  6.467],
#        [ 7.473,  6.88 ,  8.418, ...,  5.548,  1.478,  6.467],
#        [ 7.473,  6.88 ,  8.418, ...,  5.548,  1.478,  6.467],
#        ...,
#        [ 1.959,  3.503,  4.726, ..., 20.   ,  2.622, 20.   ],
#        [ 1.959,  3.503,  4.726, ..., 20.   ,  2.622, 20.   ],
#        [ 1.959,  3.503,  4.726, ..., 20.   ,  2.622, 20.   ]])

# %%
normalize = keras.layers.Normalization()
normalize.adapt(lidar_sensors)

# %%
norm_lidar_model_01 = tf.keras.Sequential([
    normalize,
    keras.Input(shape=(16, )),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1)
])

norm_lidar_model_01.compile(
    loss = tf.keras.losses.MeanSquaredError(), 
    metrics = ['accuracy'],
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
)

# %%
norm_lidar_model_01.fit(lidar_sensors, lidar_angle, epochs=50)
# Out:
# Epoch 1/50
# 363/363 [==============================] - 1s 1ms/step - loss: 93.8451 - accuracy: 0.0511
# Epoch 2/50
# 363/363 [==============================] - 0s 1ms/step - loss: 71.4892 - accuracy: 0.0519
# Epoch 3/50
# 363/363 [==============================] - 0s 1ms/step - loss: 60.0143 - accuracy: 0.0515
# Epoch 4/50
# 363/363 [==============================] - 0s 1ms/step - loss: 52.3395 - accuracy: 0.0519
# Epoch 5/50
# 363/363 [==============================] - 0s 1ms/step - loss: 46.6776 - accuracy: 0.0563
# Epoch 6/50
# 363/363 [==============================] - 0s 1ms/step - loss: 39.4706 - accuracy: 0.0540
# Epoch 7/50
# 363/363 [==============================] - 0s 1ms/step - loss: 35.5386 - accuracy: 0.0559
# Epoch 8/50
# 363/363 [==============================] - 0s 1ms/step - loss: 32.0635 - accuracy: 0.0550
# Epoch 9/50
# 363/363 [==============================] - 0s 1ms/step - loss: 28.2299 - accuracy: 0.0548
# Epoch 10/50
# 363/363 [==============================] - 0s 1ms/step - loss: 26.9734 - accuracy: 0.0539
# Epoch 11/50
# 363/363 [==============================] - 0s 1ms/step - loss: 25.9740 - accuracy: 0.0548
# Epoch 12/50
# 363/363 [==============================] - 0s 1ms/step - loss: 23.8239 - accuracy: 0.0546
# Epoch 13/50
# 363/363 [==============================] - 1s 1ms/step - loss: 21.1907 - accuracy: 0.0565
# Epoch 40/50
# 363/363 [==============================] - 0s 1ms/step - loss: 10.9028 - accuracy: 0.0524
# Epoch 41/50
# 363/363 [==============================] - 0s 1ms/step - loss: 10.1051 - accuracy: 0.0522
# Epoch 42/50
# 363/363 [==============================] - 0s 1ms/step - loss: 10.5691 - accuracy: 0.0503
# Epoch 43/50
# 363/363 [==============================] - 0s 1ms/step - loss: 9.1058 - accuracy: 0.0515
# Epoch 44/50
# 363/363 [==============================] - 0s 1ms/step - loss: 8.3612 - accuracy: 0.0529
# Epoch 45/50
# 363/363 [==============================] - 0s 1ms/step - loss: 10.1236 - accuracy: 0.0510
# Epoch 46/50
# 363/363 [==============================] - 0s 1ms/step - loss: 10.7620 - accuracy: 0.0491
# Epoch 47/50
# 363/363 [==============================] - 0s 1ms/step - loss: 8.5769 - accuracy: 0.0507
# Epoch 48/50
# 363/363 [==============================] - 1s 1ms/step - loss: 9.3167 - accuracy: 0.0500
# Epoch 49/50
# 363/363 [==============================] - 0s 1ms/step - loss: 10.3712 - accuracy: 0.0512
# Epoch 50/50
# 363/363 [==============================] - 0s 1ms/step - loss: 8.0289 - accuracy: 0.0529

# %%
val_lidar_data = pd.read_csv(
    "C:/Users/kcvan/MakeAIWork/KEVINPROJECT1/CSVfiles/validation_lidar_01.csv",
    names=["Lidar1", "Lidar2", "Lidar3", "Lidar4", "Lidar5", "Lidar6", "Lidar7", "Lidar8", "Lidar9", "Lidar10",
           "Lidar11", "Lidar12", "Lidar13", "Lidar14", "Lidar15", "Lidar16", "SteeringAngle"])

val_lidar_sensors = val_lidar_data.copy()
val_lidar_angle = val_lidar_sensors.pop('SteeringAngle')

val_lidar_sensors = np.array(val_lidar_sensors)
val_lidar_sensors
# Out:
# array([[ 7.377,  6.784,  8.326, ...,  5.466,  1.388,  6.373],
#        [ 7.377,  6.784,  8.326, ...,  5.466,  1.388,  6.373],
#        [ 7.376,  6.784,  8.326, ...,  5.465,  1.387,  6.373],
#        ...,
#        [20.   ,  3.115, 20.   , ..., 20.   ,  1.35 , 20.   ],
#        [20.   ,  3.115, 20.   , ..., 20.   ,  1.35 , 20.   ],
#        [20.   ,  3.115, 20.   , ..., 20.   ,  1.35 , 20.   ]])

# %%
norm_lidar_model_01.evaluate(val_lidar_sensors,  val_lidar_angle, verbose=2)
# Out:
# 53/53 - 0s - loss: 19.7284 - accuracy: 0.0431 - 131ms/epoch - 2ms/step
# [19.72838592529297, 0.04313960298895836]

# %%
norm_lidar_model_01.predict(val_lidar_sensors)
# Out:
# array([[-30.658],
#        [-30.657],
#        [-30.659],
#        ...,
#        [  1.499],
#        [  1.499],
#        [  1.499]], dtype=float32)

# %%
#norm_lidar_model_01.save('norm_lidar_model_01')
