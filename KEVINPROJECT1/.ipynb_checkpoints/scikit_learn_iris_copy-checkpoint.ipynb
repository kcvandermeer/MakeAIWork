# %%
import pandas as pd

# Location of dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Assign colum names to the dataset
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']

# Read dataset to pandas dataframe
irisdata = pd.read_csv(url, names=names)

# %%
irisdata.head()
# irisdata.style
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Assign data from first four columns to X variable
X = irisdata.iloc[:, 0:4]

# Assign data from first fifth columns to y variable
y = irisdata.select_dtypes(include=[object])

# %%
y.head()
# y.style
# Out:
#          Class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
y.Class.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

y = y.apply(le.fit_transform)

y.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_fa7ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa7ec_level0_col0" class="col_heading level0 col0" >Class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa7ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa7ec_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa7ec_row1_col0" class="data row1 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa7ec_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa7ec_row3_col0" class="data row3 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa7ec_row4_col0" class="data row4 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fa7ec_row5_col0" class="data row5 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fa7ec_row6_col0" class="data row6 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fa7ec_row7_col0" class="data row7 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fa7ec_row8_col0" class="data row8 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fa7ec_row9_col0" class="data row9 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fa7ec_row10_col0" class="data row10 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fa7ec_row11_col0" class="data row11 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fa7ec_row12_col0" class="data row12 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fa7ec_row13_col0" class="data row13 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fa7ec_row14_col0" class="data row14 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fa7ec_row15_col0" class="data row15 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fa7ec_row16_col0" class="data row16 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fa7ec_row17_col0" class="data row17 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fa7ec_row18_col0" class="data row18 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fa7ec_row19_col0" class="data row19 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fa7ec_row20_col0" class="data row20 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_fa7ec_row21_col0" class="data row21 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_fa7ec_row22_col0" class="data row22 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_fa7ec_row23_col0" class="data row23 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_fa7ec_row24_col0" class="data row24 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_fa7ec_row25_col0" class="data row25 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_fa7ec_row26_col0" class="data row26 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_fa7ec_row27_col0" class="data row27 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_fa7ec_row28_col0" class="data row28 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_fa7ec_row29_col0" class="data row29 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_fa7ec_row30_col0" class="data row30 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row31" class="row_heading level0 row31" >31</th>
#       <td id="T_fa7ec_row31_col0" class="data row31 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row32" class="row_heading level0 row32" >32</th>
#       <td id="T_fa7ec_row32_col0" class="data row32 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row33" class="row_heading level0 row33" >33</th>
#       <td id="T_fa7ec_row33_col0" class="data row33 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row34" class="row_heading level0 row34" >34</th>
#       <td id="T_fa7ec_row34_col0" class="data row34 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row35" class="row_heading level0 row35" >35</th>
#       <td id="T_fa7ec_row35_col0" class="data row35 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row36" class="row_heading level0 row36" >36</th>
#       <td id="T_fa7ec_row36_col0" class="data row36 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row37" class="row_heading level0 row37" >37</th>
#       <td id="T_fa7ec_row37_col0" class="data row37 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row38" class="row_heading level0 row38" >38</th>
#       <td id="T_fa7ec_row38_col0" class="data row38 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row39" class="row_heading level0 row39" >39</th>
#       <td id="T_fa7ec_row39_col0" class="data row39 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row40" class="row_heading level0 row40" >40</th>
#       <td id="T_fa7ec_row40_col0" class="data row40 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row41" class="row_heading level0 row41" >41</th>
#       <td id="T_fa7ec_row41_col0" class="data row41 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row42" class="row_heading level0 row42" >42</th>
#       <td id="T_fa7ec_row42_col0" class="data row42 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row43" class="row_heading level0 row43" >43</th>
#       <td id="T_fa7ec_row43_col0" class="data row43 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row44" class="row_heading level0 row44" >44</th>
#       <td id="T_fa7ec_row44_col0" class="data row44 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row45" class="row_heading level0 row45" >45</th>
#       <td id="T_fa7ec_row45_col0" class="data row45 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row46" class="row_heading level0 row46" >46</th>
#       <td id="T_fa7ec_row46_col0" class="data row46 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fa7ec_level0_row47" class="row_heading level0 row47" >47</th>
#       <td id="T_fa7ec_row47_col0" class="data row47 col0" >0</td>
#     </tr>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000)
mlp.fit(X_train, y_train.values.ravel())
# Out:
# MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=1000)

# %%
predictions = mlp.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[15  0  0]
#  [ 0 10  1]
#  [ 0  0  4]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      0.91      0.95        11
#            2       0.80      1.00      0.89         4
#
#     accuracy                           0.97        30
#    macro avg       0.93      0.97      0.95        30
# weighted avg       0.97      0.97      0.97        30
