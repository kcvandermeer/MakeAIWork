# %%
#pip install pandas numpy tensorflow==2.8

# %%
import pandas as pd
# print(pd.__version__)
import numpy as np
import tensorflow as tf

# ke numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)


from tensorflow.keras import layers

# %%
L_280922_14 = pd.read_csv(
    "C:/Users/kcvan/MakeAIWork/KEVINPROJECT1/DavidJeroen/tensorflow_lidar _01_test.csv",
    names=["distance 01", "distance 02","distance 03", "distance 04", "distance 05", "distance 06", "distance 07", "distance 08", "distance 09", "distance 10", "distance 11", "distance 12","distance 13", "distance 14", "distance 15", "distance 16", "angle"])

L_280922_14.head()
# Out:
#   distance 01 distance 02 distance 03 distance 04 distance 05 distance 06  \
# 0    Sensor 1    Sensor 2    Sensor 3    Sensor 4    Sensor 5    Sensor 6
# 1          20       1.641          20      3.4985      6.9423       5.401
# 2          20      1.6418          20      3.4992       6.943      5.4017
# 3          20      1.6417          20      3.4991      6.9429      5.4016
# 4          20      1.6425          20      3.4999      6.9437      5.4024
#
#   distance 07 distance 08 distance 09 distance 10 distance 11 distance 12  \
# 0    Sensor 7    Sensor 8    Sensor 9   Sensor 10   Sensor 11   Sensor 12
# 1      1.4013      6.4885          20          20          20          20
# 2      1.4018       6.489          20          20          20          20
# 3      1.4018       6.489          20          20          20          20
# 4      1.4025      6.4896          20          20          20          20
#
#   distance 13 distance 14 distance 15 distance 16           angle
# 0   Sensor 13   Sensor 14   Sensor 15   Sensor 16  Steering Angle
# 1          20          20          20          20              27
# 2          20          20          20          20              27
# 3          20          20          20          20              27
# 4          20          20          20          20              27

# %%
distanceLearning = L_280922_14.copy()
distanceLearning = distanceLearning.pop('angle')
# learningWithoutAngle.head()

# %%
distanceLearning = np.array(distanceLearning)
# distanceLearning

# %%
LearningModel = tf.keras.Sequential([
  layers.Dense(64, activation = 'relu'),
  layers.Dense(64),
  layers.Dense(64),
  layers.Dense(64),  
  layers.Dense(1)
])

LearningModel.compile(loss = tf.keras.losses.MeanSquaredError(),
                      optimizer = tf.keras.optimizers.Adam(learning_rate=0.00001))

# %%
LearningModel.fit(distanceLearning, distanceLearning, epochs=530)
# Out:
# Epoch 1/530
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [53], line 1
# ----> 1 LearningModel.fit(distanceLearning, distanceLearning, epochs=530)
#
# File ~\MakeAIWork\env\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\MakeAIWork\env\lib\site-packages\tensorflow\python\framework\func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
# -> 1147     raise e.ag_error_metadata.to_exception(e)
#    1148   else:
#    1149     raise
#
# ValueError: in user code:
#
#     File "C:\Users\kcvan\MakeAIWork\env\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\kcvan\MakeAIWork\env\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\kcvan\MakeAIWork\env\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\kcvan\MakeAIWork\env\lib\site-packages\keras\engine\training.py", line 859, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\kcvan\MakeAIWork\env\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\kcvan\MakeAIWork\env\lib\site-packages\keras\engine\input_spec.py", line 228, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" '
#
#     ValueError: Exception encountered when calling layer "sequential" (type Sequential).
#
#     Input 0 of layer "dense" is incompatible with the layer: expected min_ndim=2, found ndim=1. Full shape received: (None,)
#
#     Call arguments received:
#       • inputs=tf.Tensor(shape=(None,), dtype=string)
#       • training=True
#       • mask=None
